# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohityadav201278/Machine-Learning/blob/main/Naive_bayes_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the dataset

from sklearn.datasets import load_iris

# %%
#import machine learning model

from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
print(iris.target_names)  # ['setosa' 'versicolor' 'virginica']

# Load features (X) and target (y)
x, y = load_iris(return_X_y=True)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
#split the dataset

x_train, x_test , y_train , y_test = train_test_split(x,y,test_size=0.6, random_state=0)

# %%
#Fit the model

model = GaussianNB()
model.fit(x_train, y_train)

GaussianNB()
# Out:
# GaussianNB()

# %%
#make prediction using the model

y_pred = model.predict(x_test)

# %%
# print the accuracy or Naiye Baiyes Score

print("Naive bayes score: " , model.score(x_test , y_test))
# Out:
# Naive bayes score:  0.9444444444444444

# %%
# displaying the confusion matrix

from sklearn.metrics import confusion_matrix
cf = confusion_matrix(y_test , y_pred)
print(cf)
# Out:
# [[26  0  0]
#  [ 0 33  0]
#  [ 0  5 26]]

# %%
#visualizing it through seaborn

import seaborn as sns
sns.heatmap(cf , annot = True)
# Out:
# <Axes: >
